# %% [markdown]
# # TxData CSV Exploration
#
# This notebook downloads and explores the three TxData CSV files: `kg.csv`,
# `node.csv`, and `edges.csv`.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
from pathlib import Path
import pandas as pd

from txdata_download import download_txdata_csvs

# %%
# download_txdata_csvs(data_dir)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 data_dir = Path("~/Documents/code/TxGNN/data/txdata")
# ----> 2 download_txdata_csvs(data_dir)
#
# File ~/Documents/code/TxGNN/txdata_download.py:54, in download_txdata_csvs(data_folder_path)
#      52 else:
#      53     print(f"Downloading {file_info.name}...")
# ---> 54     _download_file(file_info.url, dest)
#      55     print(f"Saved to {dest}")
#      56 local_paths.append(dest)
#
# File ~/Documents/code/TxGNN/txdata_download.py:69, in _download_file(url, dest)
#      64 request = urllib.request.Request(
#      65     url,
#      66     headers={"User-Agent": "Mozilla/5.0"},
#      67 )
#      68 with urllib.request.urlopen(request) as response, dest.open("wb") as handle:
# ---> 69     handle.write(response.read())
#
# ...

# %%
pd.read_csv(data_dir / "../disease_files/adrenal_gland.csv")
# Out:
#     Unnamed: 0  node_id node_type  \
# 0       112874  15999.0   disease
# 1       112910  16035.0   disease
# 2       117092  20527.0   disease
# 3       120967   6640.0   disease
# 4       121051   9410.0   disease
# 5       121056  10264.0   disease
# 6       121057      4.0   disease
# 7       122156   3009.0   disease
# 8       122175   6015.0   disease
# 9       122796   7080.0   disease
# 10      123180  12675.0   disease
# 11      123657  13400.0   disease
#
#                                             node_name node_source
# 0    primary pigmented nodular adrenocortical disease       MONDO
# 1                                     Nelson syndrome       MONDO
# 2                            ectopic Cushing syndrome       MONDO
# 3                         adrenal gland hyperfunction       MONDO
# 4                                     Addison disease       MONDO
# 5               X-linked adrenal hypoplasia congenita       MONDO
# ...

# %%
kg = pd.read_csv(data_dir / "kg.csv")

# %%
node = pd.read_csv(data_dir / "node.tab", sep="\t")
edges = pd.read_csv(data_dir / "edges.tab", sep="\t")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 node = pd.read_csv(data_dir / "node.tab", sep="\t")
#       2 edges = pd.read_csv(data_dir / "edges.tab", sep="\t")
#
# ...

# %%
kg

# %%
kg = pd.read_csv(data_dir / "kg.csv")
# Out:
# /var/folders/yx/tq4qnjy56qlfjrjsdf_qtwpw0000gn/T/ipykernel_9226/2662391085.py:1: DtypeWarning: Columns (3,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   kg = pd.read_csv(data_dir / "kg.csv")

# %%
pd.DataFrame(
    {
        "rows": {"kg": len(kg), "node": len(node), "edges": len(edges)},
        "columns": {"kg": kg.shape[1], "node": node.shape[1], "edges": edges.shape[1]},
    }
)

# %%
missing = pd.DataFrame({
    "kg": kg.isna().sum(),
    "node": node.isna().sum(),
    "edges": edges.isna().sum(),
}).fillna(0).astype(int)
missing

# %%
kg["relation"].value_counts().head(20)
